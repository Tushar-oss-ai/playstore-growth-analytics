# %%
import sqlite3
import pandas as pd

df = pd.read_csv("../data/cleaned/playstore_features.csv")
df.columns = df.columns.str.replace(" ", "_")

conn = sqlite3.connect("../data/cleaned/playstore.db")
df.to_sql("apps", conn, if_exists="replace", index=False)

print(df.shape)
# Out:
# (9658, 22)

# %%
def q(sql):
    return pd.read_sql(sql, conn)

# %%
q("SELECT COUNT(*) AS total_apps FROM apps")
# Out:
#    total_apps
# 0        9658

# %%
q("""
SELECT COUNT(*)                                        AS total_apps,
       SUM(Success)                                    AS successful_apps,
       ROUND(100.0 * AVG(Success), 1)                  AS success_rate_pct,
       ROUND(AVG(Rating), 2)                           AS avg_rating,
       SUM(CASE WHEN Price = 0 THEN 1 ELSE 0 END)      AS free_apps
FROM apps
""")
# Out:
#    total_apps  successful_apps  success_rate_pct  avg_rating  free_apps
# 0        9658             3398              35.2        4.17       8904

# %%
q("""
SELECT Category,
       COUNT(*)                                        AS n_apps,
       SUM(Success)                                    AS n_success,
       ROUND(100.0 * AVG(Success), 1)                  AS success_rate_pct,
       ROUND(AVG(Rating), 2)                           AS avg_rating
FROM apps
GROUP BY Category
HAVING COUNT(*) >= 50
ORDER BY success_rate_pct DESC
""")
# Out:
#                Category  n_apps  n_success  success_rate_pct  avg_rating
# 0         ENTERTAINMENT      86         72              83.7        4.13
# 1           PHOTOGRAPHY     281        173              61.6        4.16
# 2             EDUCATION     105         61              58.1        4.35
# 3                  GAME     945        539              57.0        4.24
# 4               WEATHER      79         42              53.2        4.24
# 5              SHOPPING     202        106              52.5        4.23
# 6         VIDEO_PLAYERS     164         85              51.8        4.04
# 7         COMMUNICATION     315        140              44.4        4.12
# 8        FOOD_AND_DRINK     112         49              43.8        4.17
# 9      TRAVEL_AND_LOCAL     219         93              42.5        4.07
# 10               SOCIAL     239        100              41.8        4.25
# 11  MAPS_AND_NAVIGATION     131         54              41.2        4.04
# 12       HOUSE_AND_HOME      73         30              41.1        4.14
# 13         PRODUCTIVITY     374        147              39.3        4.18
# 14   HEALTH_AND_FITNESS     288        112              38.9        4.24
# 15               SPORTS     325        118              36.3        4.22
# 16                TOOLS     829        275              33.2        4.04
# 17   NEWS_AND_MAGAZINES     254         84              33.1        4.12
# 18               FAMILY    1877        568              30.3        4.18
# 19      PERSONALIZATION     376        110              29.3        4.33
# 20               COMICS      56         16              28.6        4.18
# 21              FINANCE     345         93              27.0        4.12
# 22            PARENTING      60         15              25.0        4.30
# 23  BOOKS_AND_REFERENCE     222         53              23.9        4.34
# 24            LIFESTYLE     369         84              22.8        4.09
# 25    AUTO_AND_VEHICLES      85         18              21.2        4.19
# 26       ART_AND_DESIGN      61         12              19.7        4.36
# 27               DATING     170         33              19.4        3.98
# 28               BEAUTY      53         10              18.9        4.28
# 29             BUSINESS     420         69              16.4        4.10
# 30   LIBRARIES_AND_DEMO      84         13              15.5        4.18
# 31               EVENTS      64          6               9.4        4.44
# 32              MEDICAL     395         18               4.6        4.17

# %%
q("""
WITH ranked AS (
    SELECT Category,
           Installs,
           ROW_NUMBER() OVER (PARTITION BY Category ORDER BY Installs DESC) AS rnk,
           SUM(Installs) OVER (PARTITION BY Category) AS category_total_installs
    FROM apps
)
SELECT Category,
       COUNT(*) AS n_apps,
       ROUND(100.0 * SUM(CASE WHEN rnk <= 10 THEN Installs ELSE 0 END)
             / MAX(category_total_installs), 1) AS top10_share_pct
FROM ranked
GROUP BY Category
HAVING COUNT(*) >= 50
ORDER BY top10_share_pct DESC
""")
# Out:
#                Category  n_apps  top10_share_pct
# 0        ART_AND_DESIGN      61             94.5
# 1                EVENTS      64             92.7
# 2    NEWS_AND_MAGAZINES     254             89.1
# 3   BOOKS_AND_REFERENCE     222             87.0
# 4      TRAVEL_AND_LOCAL     219             86.7
# 5    LIBRARIES_AND_DEMO      84             84.9
# 6                BEAUTY      53             84.6
# 7                SOCIAL     239             82.0
# 8         VIDEO_PLAYERS     164             80.1
# 9                COMICS      56             77.8
# 10    AUTO_AND_VEHICLES      85             75.3
# 11            PARENTING      60             73.0
# 12       HOUSE_AND_HOME      73             73.0
# 13        COMMUNICATION     315             72.5
# 14        ENTERTAINMENT      86             72.1
# 15              WEATHER      79             72.0
# 16  MAPS_AND_NAVIGATION     131             71.5
# 17             BUSINESS     420             68.9
# 18               DATING     170             63.9
# 19   HEALTH_AND_FITNESS     288             62.9
# 20         PRODUCTIVITY     374             60.4
# 21      PERSONALIZATION     376             58.7
# 22             SHOPPING     202             53.6
# 23               SPORTS     325             51.1
# 24              FINANCE     345             50.5
# 25                TOOLS     829             48.1
# 26            EDUCATION     105             47.6
# 27       FOOD_AND_DRINK     112             47.2
# 28              MEDICAL     395             47.0
# 29            LIFESTYLE     369             45.7
# 30          PHOTOGRAPHY     281             40.8
# 31               FAMILY    1877             30.5
# 32                 GAME     945             26.0

# %%
q("""
SELECT Price_Bucket,
       COUNT(*)                            AS n_apps,
       ROUND(100.0 * AVG(Success), 1)      AS success_rate_pct,
       ROUND(AVG(Rating), 2)               AS avg_rating
FROM apps
GROUP BY Price_Bucket
ORDER BY success_rate_pct DESC
""")
# Out:
#   Price_Bucket  n_apps  success_rate_pct  avg_rating
# 0         Free    8904              37.9        4.17
# 1        $5-10      84               4.8        4.26
# 2      $0.01-2     283               3.9        4.30
# 3         $2-5     314               2.2        4.26
# 4         $10+      73               0.0        4.13

# %%
q("""
SELECT Update_Bucket,
       COUNT(*)                            AS n_apps,
       ROUND(100.0 * AVG(Success), 1)      AS success_rate_pct
FROM apps
GROUP BY Update_Bucket
ORDER BY 
  CASE Update_Bucket
    WHEN '<=30d' THEN 1 WHEN '31-90d' THEN 2 WHEN '91-180d' THEN 3
    WHEN '181-365d' THEN 4 ELSE 5
  END
""")
# Out:
#   Update_Bucket  n_apps  success_rate_pct
# 0         <=30d    2936              56.7
# 1        31-90d    1828              38.9
# 2       91-180d    1158              23.5
# 3      181-365d    1320              22.9
# 4          >1yr    2416              18.5

# %%
q("""
SELECT Size_Bucket,
       COUNT(*)                            AS n_apps,
       ROUND(100.0 * AVG(Success), 1)      AS success_rate_pct
FROM apps
WHERE Size_Bucket IS NOT NULL
GROUP BY Size_Bucket
ORDER BY 
  CASE Size_Bucket
    WHEN '<5MB' THEN 1 WHEN '5-15MB' THEN 2 WHEN '15-30MB' THEN 3
    WHEN '30-60MB' THEN 4 ELSE 5
  END
""")
# Out:
#   Size_Bucket  n_apps  success_rate_pct
# 0        <5MB    2317              13.8
# 1      5-15MB    2494              25.5
# 2     15-30MB    1719              33.7
# 3     30-60MB    1301              46.5
# 4    60-100MB     600              58.3
